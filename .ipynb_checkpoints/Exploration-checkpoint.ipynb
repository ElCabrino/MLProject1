# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %%
# %load helpers.py
"""some helper functions for project 1."""
import csv
import numpy as np

MIN_MAX_VALUES = {
    0:  (0,  500), 1 : (0,  220), 2: (0, 300),  3: (0, 320),          
    5:  (0, 2300),                              8: (0, 100),  9: (0, 1000),         
    10: (0,    6),                             13: (0, 150),
                   16: (0,  180),                            19: (0,  210),
                   21: (0, 1000),              23: (0, 500),
                   26: (0,  250),                            29: (0,  500),
}

# %%
y, x, ids = load_csv_data('data/train.csv', sub_sample=True)

# %% [markdown]
# # Raw Data
#
# *"How much data dowe have in total?"*

# %%
print("- There are {} data points in the dataset".format(x.shape[0]))
print("- There are {} features in x".format(x.shape[1]))
# Out:
# - There are 5000 data points in the dataset
# - There are 30 features in x

# %%
def describe_features(x):
    mean_x = np.nanmean(x, axis=0)
    var_x = np.nanvar(x, axis=0)
    max_x = np.nanmax(x, axis=0)
    min_x = np.nanmin(x, axis=0)
    nan_x = np.sum(np.isnan(x), axis=0)
    
    print(f'Shape: {x.shape}')
    print('ID |    Mean    |    Var     |    Min     |    Max     |   #NaN   |')
    print('---|------------|------------|------------|------------|----------|')
    
    for f in range(0, x.shape[1]):
        mean = '{0:.3f}'.format(mean_x[f]).rjust(10)
        var = '{0:.3f}'.format(var_x[f]).rjust(10)
        maxi = '{0:.3f}'.format(max_x[f]).rjust(10)
        mini = '{0:.3f}'.format(min_x[f]).rjust(10)
        nani = str(nan_x[f]).rjust(8)
        identifier = str(f).rjust(2)
    
        print('{} | {} | {} | {} | {} | {} |'.format(identifier, mean, var, mini, maxi, nani))

# %% [markdown]
# *"What does the data look like?"*

# %%
describe_features(x)
# Out:
# Shape: (5000, 30)
# ID |    Mean    |    Var     |    Min     |    Max     |   #NaN   |
# ---|------------|------------|------------|------------|----------|
#  0 |    -66.570 | 178522.382 |   -999.000 |    977.515 |        0 |
#  1 |     50.266 |   1227.770 |      0.011 |    256.371 |        0 |
#  2 |     81.007 |   1712.009 |      9.463 |    658.494 |        0 |
#  3 |     57.243 |   3945.247 |      0.000 |    585.661 |        0 |
#  4 |   -703.584 | 208562.497 |   -999.000 |      7.544 |        0 |
#  5 |   -596.237 | 432395.561 |   -999.000 |   3056.908 |        0 |
#  6 |   -704.530 | 207232.544 |   -999.000 |     15.228 |        0 |
#  7 |      2.376 |      0.627 |      0.256 |      5.423 |        0 |
#  8 |     18.975 |    495.589 |      0.000 |    257.324 |        0 |
#  9 |    157.925 |  13633.526 |     46.227 |   1279.985 |        0 |
# 10 |      1.448 |      0.705 |      0.136 |      9.955 |        0 |
# 11 |     -0.159 |      1.403 |     -1.414 |      1.414 |        0 |
# 12 |   -704.155 | 207756.906 |   -999.000 |      1.000 |        0 |
# 13 |     37.971 |    436.991 |     20.001 |    301.229 |        0 |
# 14 |     -0.008 |      1.487 |     -2.468 |      2.463 |        0 |
# 15 |     -0.000 |      3.213 |     -3.141 |      3.141 |        0 |
# 16 |     46.340 |    446.602 |     26.005 |    263.690 |        0 |
# 17 |     -0.020 |      1.613 |     -2.482 |      2.480 |        0 |
# 18 |      0.115 |      3.359 |     -3.141 |      3.141 |        0 |
# 19 |     42.210 |   1033.956 |      0.537 |    404.422 |        0 |
# 20 |      0.029 |      3.264 |     -3.139 |      3.141 |        0 |
# 21 |    209.379 |  16697.123 |     24.416 |   1391.891 |        0 |
# 22 |      0.984 |      0.951 |      0.000 |      3.000 |        0 |
# 23 |   -345.453 | 283494.766 |   -999.000 |    738.235 |        0 |
# 24 |   -396.614 | 238905.669 |   -999.000 |      4.464 |        0 |
# 25 |   -396.605 | 238912.765 |   -999.000 |      3.141 |        0 |
# 26 |   -687.271 | 232559.963 |   -999.000 |    358.433 |        0 |
# 27 |   -704.297 | 207557.795 |   -999.000 |      4.496 |        0 |
# 28 |   -704.331 | 207509.868 |   -999.000 |      3.140 |        0 |
# 29 |     73.614 |  10032.782 |      0.000 |   1104.776 |        0 |

# %% [markdown]
# # Clean Data

# %%
# %load features.py
# This file contains all functions related to transforming and cleaning
# the features
import numpy as np

MIN_MAX_VALUES = {
    0:  (0,  500), 1 : (0,  220), 2: (0, 300),  3: (0, 320),          
    5:  (0, 2300),                              8: (0, 100),  9: (0, 1000),         
    10: (0,    6),                             13: (0, 150),
                   16: (0,  180),                            19: (0,  210),
                   21: (0, 1000),              23: (0, 500),
                   26: (0,  250),                            29: (0,  500),
}

def build_poly(x, degree):
    """polynomial basis functions for input data x, for j=0 up to j=degree."""
    # this function should return the matrix formed
    # by applying the polynomial basis to the input data
    return np.array([np.concatenate([[1.0]] + [[xi ** d for d in range(1, degree+1)] for xi in row]) for row in x])

def standardize(x):
    """Standardize the original data set."""
    mean_x = np.mean(x)
    x = x - mean_x
    std_x = np.std(x)
    x = x / std_x
    return x, mean_x, std_x

def standardize_all(x):
    x = np.apply_along_axis(lambda xi: standardize(xi)[0], 0, x)
    return x

def clamp(data, min_value, max_value, mode='clamp'):
    if mode == 'clamp':
        data[data > max_value] = max_value
        data[data < min_value] = min_value
    else:
        data[data > max_value] = np.NaN
        data[data < min_value] = np.NaN

def remove_errors(data):
    data = data.copy()
    data[data == -999.0] = np.NaN
    return data
        
def remove_outliers(data, mode='clamp'):
    data = data.copy()
    
    for key, value in MIN_MAX_VALUES.items():
        clamp(data[:, key], value[0], value[1], mode)

    return data

def remove_nan_features(x):
    data = data[:, ~np.any(np.isnan(x), axis=0)]
    return data

def remove_nan_samples(x, y):
    index = np.any(np.isnan(x), axis=1)

    x = x[~index]
    y = y[~index]
    
    data = data[:, ~np.any(np.isnan(x), axis=0)]
    
    return data

def clean_data(x):

    # Copy so that we don't touch the original data
    x = x.copy()

    # Replace wrong values
    x[x == -999.0] = np.NaN

    x = x[:, ~np.any(np.isnan(x), axis=0)]
    # x[x > 5]

#     x[x > 5] = np.NaN
#     x[x < -5] = np.NaN

    x = np.apply_along_axis(lambda xi: standardize(xi)[0], 0, x)
    # x[x > 5] = np.NaN
    # x[x < -5] = np.NaN

    return x

def clean_data_2(x, y):

        # Copy so that we don't touch the original data
    x = x.copy()

    # Replace wrong values
    x = remove_errors(x)
#     x[x == -999.0] = np.NaN

    # Remove outliers
    x = remove_outliers(x)

    index = np.any(np.isnan(x), axis=1)

    x = x[~index]
    y = y[~index]

    x = np.apply_along_axis(lambda xi: standardize(xi)[0], 0, x)

    return x, y

# %%
def standardize(x):
    """Standardize the original data set."""
    mean_x = np.mean(x)
    x = x - mean_x
    std_x = np.std(x)
    x = x / std_x
    return x, mean_x, std_x

def clean_data(x):
    
    # Copy so that we don't touch the original data
    x = x.copy()
    
    # Replace wrong values
#     x[x == -999.0] = np.NaN
    
    # Remove outliers
    x = remove_errors(x)
    x = remove_outliers(x)
    x = standardize_all(x)
    x = remove_nan_features(x)

#     x = x[~np.any(np.isnan(x), axis=1)]

    return x

def count_of_nans(x):
    
    x_clean[:][np.isnan(x_clean[:]) == True].shape[0]

# %%
x_clean = clean_data(x)
describe_features(x_clean)
# x_clean.shape
# Out:
# Shape: (5000, 30)
# ID |    Mean    |    Var     |    Min     |    Max     |   #NaN   |
# ---|------------|------------|------------|------------|----------|
#  0 |        nan |        nan |        nan |        nan |     5000 |
#  1 |      0.000 |      1.000 |     -1.439 |      4.862 |        0 |
#  2 |      0.000 |      1.000 |     -1.878 |      5.796 |        0 |
#  3 |      0.000 |      1.000 |     -0.941 |      4.360 |        0 |
#  4 |        nan |        nan |        nan |        nan |     5000 |
#  5 |        nan |        nan |        nan |        nan |     5000 |
#  6 |        nan |        nan |        nan |        nan |     5000 |
#  7 |      0.000 |      1.000 |     -2.677 |      3.848 |        0 |
#  8 |      0.000 |      1.000 |     -0.934 |      4.100 |        0 |
#  9 |     -0.000 |      1.000 |     -0.964 |      7.273 |        0 |
# 10 |     -0.000 |      1.000 |     -1.611 |      5.613 |        0 |
# 11 |     -0.000 |      1.000 |     -1.060 |      1.328 |        0 |
# 12 |        nan |        nan |        nan |        nan |     5000 |
# 13 |     -0.000 |      1.000 |     -0.901 |      5.673 |        0 |
# 14 |     -0.000 |      1.000 |     -2.018 |      2.026 |        0 |
# 15 |      0.000 |      1.000 |     -1.752 |      1.752 |        0 |
# 16 |     -0.000 |      1.000 |     -0.977 |      6.437 |        0 |
# 17 |      0.000 |      1.000 |     -1.939 |      1.968 |        0 |
# 18 |      0.000 |      1.000 |     -1.777 |      1.651 |        0 |
# 19 |      0.000 |      1.000 |     -1.363 |      5.528 |        0 |
# 20 |     -0.000 |      1.000 |     -1.753 |      1.723 |        0 |
# 21 |      0.000 |      1.000 |     -1.446 |      6.190 |        0 |
# 22 |      0.000 |      1.000 |     -1.009 |      2.067 |        0 |
# 23 |        nan |        nan |        nan |        nan |     5000 |
# 24 |        nan |        nan |        nan |        nan |     5000 |
# 25 |        nan |        nan |        nan |        nan |     5000 |
# 26 |        nan |        nan |        nan |        nan |     5000 |
# 27 |        nan |        nan |        nan |        nan |     5000 |
# 28 |        nan |        nan |        nan |        nan |     5000 |
# 29 |      0.000 |      1.000 |     -0.770 |      4.529 |        0 |
# /Users/julienperrenoud/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: Mean of empty slice
#
# /Users/julienperrenoud/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/julienperrenoud/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: All-NaN slice encountered
#   after removing the cwd from sys.path.
# /Users/julienperrenoud/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: All-NaN slice encountered
#   """

# %% [markdown]
# *"What does the clean data look like?"*

# %%
# describe
# x_clean[np.isnan(x_clean) == False]

# %%
def histo_feature(data, i, ax=None, b=None):
    
    indexes = ~np.isnan(data[:,i])
    
    if b == None:
        color = 'blue'
    elif b:
        indexes = indexes & (y == 1)
        color='green'
    else:
        indexes = indexes & (y == -1)
        color='red'
        
    if ax ==None:
        ax = plt
    
    ax.hist(data[:,i][indexes], 250, facecolor=color, alpha=0.75)
    
def histo_features(data, b=None):
    fig = plt.figure(figsize = (15,15))
    
    for i in range(0, 30):
        ax = fig.add_subplot(6,5,i+1)
        histo_feature(data, i, ax=ax, b=b)

# %%
# histo_features(x_clean)

# %%
# histo_features(x_clean, b=True)

# %%
# histo_features(x_clean, b=False)

# %%
def clamp(data, max_value):
    data[data > max_value] = np.NaN

def remove_outliers(data):
    data = data.copy()
    clamp(data[:, 0], 500)
    clamp(data[:, 1], 220)
    clamp(data[:, 2], 300)
    clamp(data[:, 3], 320)
    # 4
    clamp(data[:, 5], 2300)
    # 6
    # 7
    clamp(data[:, 8], 100)
    clamp(data[:, 9], 1000)
    clamp(data[:, 10], 6)
    # 11
    # 12
    clamp(data[:, 13], 150)
    # 14
    # 15
    clamp(data[:, 16], 180)
    # 17 
    # 18
    clamp(data[:, 19], 210)
    # 20
    clamp(data[:, 21], 1000)
    # 22
    clamp(data[:, 23], 500)
    # 24
    # 25
    clamp(data[:, 26], 250)
    # 27
    # 28
    clamp(data[:, 29], 500)
    
    return data

# %%
x_clamped = remove_outliers(x_clean)

# %%
histo_features(x_clamped)

# %%
# histo_features(x_clamped, b=True)

# %%
# histo_features(x_clamped, b=False)

# %%
def compare_features(data):
    fig = plt.figure(figsize = (15,150))
    
    for i in range(0, 60):
        ax = fig.add_subplot(30,2,i+1)
        histo_feature(data, int(i/2.0), ax=ax, b=(i%2==0))

# %%
compare_features(x_clamped)

# %% [markdown]
# ### Normalization

# %%
def standardize(x):
    """Standardize the original data set."""
    mean_x = np.mean(x)
    x = x - mean_x
    std_x = np.std(x)
    x = x / std_x
    return x, mean_x, std_x

# %%
x_std = np.vectorize(lambda x: standardize(x))(x_clean)
# Out:
# /Users/julienperrenoud/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in double_scalars

# %%
x_test = np.apply_along_axis(lambda x: standardize(x)[0], 0, x_clean)
mask = np.all(np.isnan(x_test), axis=0)
x_test = x_test[:, ~mask]

# describe_features(x_test.dropna())

describe_features(x_test)
# d[:,~np.all(np.isnan(d), axis=0)]
# Out:
# ID |    Mean    |    Var     |    Min     |    Max     |   #NaN   |
# ---|------------|------------|------------|------------|----------|
#  0 |     -0.000 |      1.000 |     -1.434 |      5.882 |        0 |
#  1 |      0.000 |      1.000 |     -1.729 |     13.957 |        0 |
#  2 |      0.000 |      1.000 |     -0.911 |      8.413 |        0 |
#  3 |      0.000 |      1.000 |     -2.677 |      3.848 |        0 |
#  4 |     -0.000 |      1.000 |     -0.852 |     10.707 |        0 |
#  5 |      0.000 |      1.000 |     -0.957 |      9.610 |        0 |
#  6 |      0.000 |      1.000 |     -1.562 |     10.133 |        0 |
#  7 |     -0.000 |      1.000 |     -1.060 |      1.328 |        0 |
#  8 |      0.000 |      1.000 |     -0.860 |     12.593 |        0 |
#  9 |     -0.000 |      1.000 |     -2.018 |      2.026 |        0 |
# 10 |      0.000 |      1.000 |     -1.752 |      1.752 |        0 |
# 11 |      0.000 |      1.000 |     -0.962 |     10.285 |        0 |
# 12 |      0.000 |      1.000 |     -1.939 |      1.968 |        0 |
# 13 |      0.000 |      1.000 |     -1.777 |      1.651 |        0 |
# 14 |      0.000 |      1.000 |     -1.296 |     11.264 |        0 |
# 15 |     -0.000 |      1.000 |     -1.753 |      1.723 |        0 |
# 16 |     -0.000 |      1.000 |     -1.431 |      9.151 |        0 |
# 17 |      0.000 |      1.000 |     -1.009 |      2.067 |        0 |
# 18 |     -0.000 |      1.000 |     -0.735 |     10.295 |        0 |
